# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaisa290/FUNPRO/blob/main/CLASE_1_ESTRICTURAS_DE_SELECCION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Estructura de selecc

# %% [markdown]
# #Estructura de selecccion
# Evaluan una condicion de verdad
#
# 1. IF/ELSE
# 2. IF TERNARIO
# 3. IF/ELIF/ESE
# 4. CASE

# %% [markdown]
# ##1. IF/ELSE
# Solo tiene dos posibles respuestas (V) O (F).
#
# Sintaxis
# ````````
# if (condicion):
#  aqui se ejecuta codigo **si** la condicion es verdadera.
#
# else:
#   aqui se ejecuta el codigo **si** la condicion es falsa.

# %%
lluvia=input("Esta lloviendo? ")
# Out:
# Esta lloviendo? no

# %%
if lluvia=="si":
  print("te recomiendo ir al parque")
else:
  print("cierra las ventanas")
# Out:
# cierra las ventanas

# %%
if lluvia=="no":
  print("te recomiendo ir al parque.")
else:
  if lluvia=="un poquito":
    print("te sugiero que si vas al parque lleve sombrilla")
  else:
    if lluvia=="si":
     print("cierra ls ventanas")
    else:
     print("resguardese")
# Out:
# te recomiendo ir al parque.

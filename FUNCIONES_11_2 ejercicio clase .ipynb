# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaisa290/FUNPRO/blob/main/FUNCIONES_11_2%20ejercicio%20clase%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cuantas notas estuieron por encima de 3 y cual es el promedio

# %% [markdown]
# ![4947581315024882471.jpg](data:image/jpeg;base64,...)

# %%
def tomar_notas():
  n_notas=int(input("Ingrese la cantidad de notas"))
  notas=[]
  for i in range(n_notas):
    nota=float(input(f"Ingrese la nota {i+1}"))
    notas.append(nota)

  suma=0
  cont=0

  for i in range(n_notas):
    print(f"nota {i+1}: {notas[i]}")
    suma=suma+notas[i]
    if notas [i} >3:
    cont= cont+1
# Out:
#   File "/tmp/ipython-input-3038623200.py", line 14
#     if notas [i} >3:
#                ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
rint(notas[i])
    if notas[i]>3:
      suma=suma+notas[i]
      cont=cont+1

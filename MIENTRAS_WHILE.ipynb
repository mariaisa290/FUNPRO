# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaisa290/FUNPRO/blob/main/MIENTRAS_WHILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2025-10-21 at 8.35.52 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-10-21 at 8.35.53 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# TAREA
# ![WhatsApp Image 2025-09-17 at 8.32.31 PM.jpeg](data:image/jpeg;base64,...)

# %%
humedad_suelo=float(input("ingrese la humedad: "))
prob_lluvia=float(input("ingrese la probabilidad de lluvia: "))
temp_c=float(input("ingrese la temperatura: "))
hora=int(input("horas: "))
if humedad_suelo==0 or prob_lluvia==0 or temp_c==0 or hora==0:
  print("Error sensor")
else:
  if prob_lluvia>=70:
    print("No regar")
  else:
    if humedad_suelo<35 or prob_lluvia<40 or (horas>=11 and horas<=15):
      print("No regar")
    elif humedad_suelo>35:
      print("no regar")
    elif prob_lluvia>40:
      print("no regar")
    elif (horas>=11 and horas<=15) and temp_c>35:
      print("no regar")
    elif (horas>=11 and horas<=15) and temp_c<35:
      print("si regar")
# Out:
# ingrese la humedad: 30
# ingrese la probabilidad de lluvia: 45
# ingrese la temperatura: 20
# horas: 5
# No regar

# %% [markdown]
# ![WhatsApp Image 2025-09-17 at 11.39.21 PM.jpeg](data:image/jpeg;base64,...)

# %%
#Sistema de tarifacion de energia
kwh=float (input("ingrese kwh consumidos"))
estrato=float(input("ingrese su estrato"))
dia_semana=str(input("ingrese si es dia festivo o entre semana"))
regarco=float
descuento=float
base=float
base=kwh*620
if estrato<=2:
  descuento=base*0.2
  print(f"tienes un descuento del {descuento}")
elif dia_semana==festivo and kwh>1000:
 recargo=kwh*800
 print(f"tienes un recargo de {recargo}")
elif kwh>0 or estrato>6 or estrato<0:
  print("error, programa una visita lo mas rapido posible")
# Out:
# ingrese kwh consumidos500
# ingrese su estrato1
# ingrese si es dia festivo o entre semanafestivo
# tienes un descuento del 62000.0
